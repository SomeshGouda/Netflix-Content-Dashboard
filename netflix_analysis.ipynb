-- %%
#Netflix Data Analysis Project

#Objective:
#Analyze Netflix content and identify trends in genres, ratings, countries, and release years.
import pandas as pd

df = pd.read_csv("netflix_dashboard/netflix_titles.csv")

df.head()
-- Out:
--   show_id     type                  title         director  \
-- 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
-- 1      s2  TV Show          Blood & Water              NaN
-- 2      s3  TV Show              Ganglands  Julien Leclercq
-- 3      s4  TV Show  Jailbirds New Orleans              NaN
-- 4      s5  TV Show           Kota Factory              NaN
--
--                                                 cast        country  \
-- 0                                                NaN  United States
-- 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
-- 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
-- 3                                                NaN            NaN
-- 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
--
--            date_added  release_year rating   duration  \
-- 0  September 25, 2021          2020  PG-13     90 min
-- 1  September 24, 2021          2021  TV-MA  2 Seasons
-- ...

-- %%
df.shape
-- Out:
-- (8807, 12)

-- %%
df.columns
-- Out:
-- Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
--        'release_year', 'rating', 'duration', 'listed_in', 'description'],
--       dtype='object')

-- %%
df.info()
-- Out:
-- <class 'pandas.core.frame.DataFrame'>
-- RangeIndex: 8807 entries, 0 to 8806
-- Data columns (total 12 columns):
--  #   Column        Non-Null Count  Dtype
-- ---  ------        --------------  -----
--  0   show_id       8807 non-null   object
--  1   type          8807 non-null   object
--  2   title         8807 non-null   object
--  3   director      6173 non-null   object
--  4   cast          7982 non-null   object
--  5   country       7976 non-null   object
--  6   date_added    8797 non-null   object
--  7   release_year  8807 non-null   int64
--  8   rating        8803 non-null   object
--  9   duration      8804 non-null   object
--  10  listed_in     8807 non-null   object
--  11  description   8807 non-null   object
-- dtypes: int64(1), object(11)
-- memory usage: 825.8+ KB

-- %%
df.isnull().sum()
-- Out:
-- show_id            0
-- type               0
-- title              0
-- director        2634
-- cast             825
-- country          831
-- date_added        10
-- release_year       0
-- rating             4
-- duration           3
-- listed_in          0
-- description        0
-- dtype: int64

-- %%
df.duplicated().sum()
#means is there any duplicated value or not
-- Out:
-- np.int64(0)

-- %%
df['director']= df['director'].fillna('Unknown')

-- %%
df.isnull().sum()
-- Out:
-- show_id           0
-- type              0
-- title             0
-- director          0
-- cast            825
-- country         831
-- date_added       10
-- release_year      0
-- rating            4
-- duration          3
-- listed_in         0
-- description       0
-- dtype: int64

-- %%
df['cast'] = df['cast'].fillna('Not Available')

-- %%
df.isnull().sum()
-- Out:
-- show_id           0
-- type              0
-- title             0
-- director          0
-- cast              0
-- country         831
-- date_added       10
-- release_year      0
-- rating            4
-- duration          3
-- listed_in         0
-- description       0
-- dtype: int64

-- %%
df['country'] = df['country'].fillna('Unknown')

-- %%
df.isnull().sum()
-- Out:
-- show_id          0
-- type             0
-- title            0
-- director         0
-- cast             0
-- country          0
-- date_added      10
-- release_year     0
-- rating           4
-- duration         3
-- listed_in        0
-- description      0
-- dtype: int64

-- %%
df['date_added'].head()
-- Out:
-- 0    September 25, 2021
-- 1    September 24, 2021
-- 2    September 24, 2021
-- 3    September 24, 2021
-- 4    September 24, 2021
-- Name: date_added, dtype: object

-- %%
df['date_added'] = df['date_added'].fillna('Not Available')

-- %%
df.isnull().sum()
-- Out:
-- show_id         0
-- type            0
-- title           0
-- director        0
-- cast            0
-- country         0
-- date_added      0
-- release_year    0
-- rating          4
-- duration        3
-- listed_in       0
-- description     0
-- dtype: int64

-- %%
df['rating']= df['rating'].fillna('Not Rated')

-- %%
df.isnull().sum()
-- Out:
-- show_id         0
-- type            0
-- title           0
-- director        0
-- cast            0
-- country         0
-- date_added      0
-- release_year    0
-- rating          0
-- duration        3
-- listed_in       0
-- description     0
-- dtype: int64

-- %%
#Data Cleaning

#Movies vs TV Shows Analysis

#Country Analysis

#Rating Analysis

#Genre Analysis

#Release Year Analysis

df['duration'] = df['duration'].fillna('Unknown')

-- %%
df.isnull().sum()
-- Out:
-- show_id         0
-- type            0
-- title           0
-- director        0
-- cast            0
-- country         0
-- date_added      0
-- release_year    0
-- rating          0
-- duration        0
-- listed_in       0
-- description     0
-- dtype: int64

-- %%
df.to_csv('netflix_cleaned.csv', index=False)

-- %%
df['type'].value_counts()
-- Out:
-- type
-- Movie      6131
-- TV Show    2676
-- Name: count, dtype: int64

-- %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='type', data=df)
plt.title('Movies vs TV Shows on Netflix')
plt.show()

-- %%
df['country'].value_counts().head(10)
-- Out:
-- country
-- United States     2818
-- India              972
-- Unknown            831
-- United Kingdom     419
-- Japan              245
-- South Korea        199
-- Canada             181
-- Spain              145
-- France             124
-- Mexico             110
-- Name: count, dtype: int64

-- %%
top_countries = df['country'].value_counts().head(10)

top_countries.plot(kind='bar')

plt.title('Top 10 Countries by Netflix Content')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.show()

-- %%
df['rating'].value_counts().head(10)
-- Out:
-- rating
-- TV-MA    3207
-- TV-14    2160
-- TV-PG     863
-- R         799
-- PG-13     490
-- TV-Y7     334
-- TV-Y      307
-- PG        287
-- TV-G      220
-- NR         80
-- Name: count, dtype: int64

-- %%
df['rating'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

-- %%
df['listed_in'].value_counts().head(10)
-- Out:
-- listed_in
-- Dramas, International Movies                        362
-- Documentaries                                       359
-- Stand-Up Comedy                                     334
-- Comedies, Dramas, International Movies              274
-- Dramas, Independent Movies, International Movies    252
-- Kids' TV                                            220
-- Children & Family Movies                            215
-- Children & Family Movies, Comedies                  201
-- Documentaries, International Movies                 186
-- Dramas, International Movies, Romantic Movies       180
-- Name: count, dtype: int64

-- %%
df['listed_in'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=90)#means the genres are big titles so don't overlap i use xticks
plt.show()

-- %%
df['release_year'].value_counts().sort_index()
-- Out:
-- release_year
-- 1925       1
-- 1942       2
-- 1943       3
-- 1944       3
-- 1945       4
--         ...
-- 2017    1032
-- 2018    1147
-- 2019    1030
-- 2020     953
-- 2021     592
-- Name: count, Length: 74, dtype: int64

-- %%
df['release_year'].value_counts().sort_index().plot()

plt.title('Netflix Content Released Over Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.show()

-- %%
(df['type'].value_counts(normalize=True) * 100).round(2)
-- Out:
-- type
-- Movie      69.62
-- TV Show    30.38
-- Name: proportion, dtype: float64

-- %%
(df['country'].value_counts(normalize=True) * 100).round(2).head(10)
-- Out:
-- country
-- United States     32.00
-- India             11.04
-- Unknown            9.44
-- United Kingdom     4.76
-- Japan              2.78
-- South Korea        2.26
-- Canada             2.06
-- Spain              1.65
-- France             1.41
-- Mexico             1.25
-- Name: proportion, dtype: float64

-- %%
(df['rating'].value_counts(normalize=True) * 100).round(2).head(10)
-- Out:
-- rating
-- TV-MA    36.41
-- TV-14    24.53
-- TV-PG     9.80
-- R         9.07
-- PG-13     5.56
-- TV-Y7     3.79
-- TV-Y      3.49
-- PG        3.26
-- TV-G      2.50
-- NR        0.91
-- Name: proportion, dtype: float64

-- %%
df.groupby('type')['show_id'].count()
-- Out:
-- type
-- Movie      6131
-- TV Show    2676
-- Name: show_id, dtype: int64

-- %%
df['release_year'].value_counts().sort_values(ascending=False).head(10)
-- Out:
-- release_year
-- 2018    1147
-- 2017    1032
-- 2019    1030
-- 2020     953
-- 2016     902
-- 2021     592
-- 2015     560
-- 2014     352
-- 2013     288
-- 2012     237
-- Name: count, dtype: int64

-- %%
df.shape
-- Out:
-- Error: No connection selected.
